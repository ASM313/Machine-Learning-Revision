# %% [markdown]
# # Exploratory Data Analysis
#
# > Univariate
# - Categorical data

# %% [markdown]
# ``1. Countplot 2. Pie Chart  ``

# %% [markdown]
# - Numerical data

# %% [markdown]
# `1. Distplot 2. Boxplot`

# %%
import  pandas as pd
import os
import seaborn as sb
import matplotlib.pyplot as plt

# %%
os.chdir("G:\Machine-Learning-Revision")
df = pd.read_csv("civil_data.csv")

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education.num',
#        'marital.status', 'occupation', 'relationship', 'race', 'sex',
#        'capital.gain', 'capital.loss', 'hours.per.week', 'native.country',
#        'income'],
#       dtype='object')

# %%
# Countplot

sb.countplot(df['education'])
# Out:
# C:\Users\ATIQ MANSOORI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='education', ylabel='count'>

# %%
# Pie chart

df['relationship'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='relationship'>

# %%
# Distplot

sb.displot(df['capital.gain'])

# %%
# Boxplot

sb.boxplot(df['hours.per.week'])
# Out:
# C:\Users\ATIQ MANSOORI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='hours.per.week'>
